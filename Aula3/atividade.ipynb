# %%
import pandas as pd
#python -m pip install openpyxl
path = r"C:\Users\Paolo\Documents\COTEMIG\Python\Aula3\Tabela_3_Areas_gerais_de_formacao_na_graduacao.xlsx"

# %%
tabela = pd.read_excel(path, engine="openpyxl")
tabela

# %%
bruto = pd.read_excel(path, engine="openpyxl", header=None)
#header le sem usar a 1ª linha como nome de coluna (senão o título vira "coluna")

tabela = bruto.iloc[3:36].copy()
tabela.columns = [
    "uf_regiao",
    "Total_Pessoas",
    "total_homens",
    "total_mulheres",
    "Total_Ciência, Tecnologia, Engenharias e Matemática",
    "Total_Ciência, Tecnologia, Engenharias e Matemática_Homens",
    "Total_Ciência, Tecnologia, Engenharias e Matemática_Mulheres",
    "Total_Educação, Serviços pessoais, Saúde e Bem-estar",
    "Total_Educação, Serviços pessoais, Saúde e Bem-estar_Homens",
    "Total_Educação, Serviços pessoais, Saúde e Bem-estar_Mulheres"
]
tabela

# %%
#Transforma os dados em números (para pode fazer calculos)

for col in tabela.columns[1:]:
    tabela[col] = pd.to_numeric(tabela[col])

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste","Brasil"]

mascara_regioes = tabela["uf_regiao"].isin(regioes)

formacao_total = tabela.loc[
    mascara_regioes,
    ["uf_regiao", "total_homens", "total_mulheres"]
]
formacao_total

# %%
formacao_stem = tabela.loc[
    mascara_regioes,
    ["uf_regiao","Total_Ciência, Tecnologia, Engenharias e Matemática_Homens","Total_Ciência, Tecnologia, Engenharias e Matemática_Mulheres"]
]

Total_HM_CienciasEtc

# %%
formacao_saude = tabela.loc[
    mascara_regioes,
    ["uf_regiao","Total_Educação, Serviços pessoais, Saúde e Bem-estar_Homens","Total_Educação, Serviços pessoais, Saúde e Bem-estar_Mulheres"]
]
Total_HM_EducacaoEtc

# %%
print(formacao_total["uf_regiao"].unique())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Barras agrupadas: homens x mulheres no Brasil (três recortes)
brasil = pd.DataFrame(
    {
        "area": ["Graduação (total)", "STEM", "Saúde / educação"],
        "homens": [
            formacao_total.loc[formacao_total["uf_regiao"] == "Brasil", "total_homens"].item(),
            formacao_stem.loc[formacao_stem["uf_regiao"] == "Brasil", "homens"].item(),
            formacao_saude.loc[formacao_saude["uf_regiao"] == "Brasil", "homens"].item(),
        ],
        "mulheres": [
            formacao_total.loc[formacao_total["uf_regiao"] == "Brasil", "total_mulheres"].item(),
            formacao_stem.loc[formacao_stem["uf_regiao"] == "Brasil", "mulheres"].item(),
            formacao_saude.loc[formacao_saude["uf_regiao"] == "Brasil", "mulheres"].item(),
        ],
    }
)
brasil_long = brasil.melt(id_vars="area", var_name="sexo", value_name="pessoas")

fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(data=brasil_long, x="area", y="pessoas", hue="sexo", ax=ax)
ax.set_title("Brasil: pessoas com graduação, por área e sexo")
ax.set_xlabel("Área")
ax.set_ylabel("Pessoas")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
